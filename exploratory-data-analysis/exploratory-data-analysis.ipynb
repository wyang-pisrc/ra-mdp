# %% [markdown]
# ## Setup

# %%
# Connect using pyodbc, sqlalchemy, and pandas
import sqlalchemy
import pandas as pd

server = "sqlsvr-0092-mdp-02.85f8a2f57eaf.database.windows.net"
database = "GlobalMarketing_DW"
username = "pisrc-inkoo"
with open("./db-pass") as f:
    password = f.read()
driver = "ODBC Driver 17 for SQL Server"

engine = sqlalchemy.create_engine(
    f"mssql+pyodbc://{username}:{password}@{server}/{database}?driver={driver.replace(' ', '+')}"
)


def query_db(query, params=None):
    return pd.read_sql(query, engine, params=params)


df = query_db("SELECT @@version;")
print(df[""][0])
# Out:
# Microsoft SQL Azure (RTM) - 12.0.2000.8
# 	Jan 26 2022 22:23:07
# 	Copyright (C) 2019 Microsoft Corporation

# %% [markdown]
# # `bi_dds.DimCustomerMaster`

# %%
# Number of entries
query_db(
    """
    SELECT COUNT(*)
    FROM bi_dds.DimCustomerMaster;
    """
)
# Out:
#
# 0  2289654

# %%
# Number of distinct entries
query_db(
    """
    SELECT COUNT(DISTINCT CustomerMasterKey)
    FROM bi_dds.DimCustomerMaster;
    """
)
# Out:
#
# 0  2289654

# %%
# Columns of interest
query_db(
    """
    SELECT TOP 10
        CustomerMasterKey,
        AccountName,
        State,
        Office,
        Region,
        Country,
        Status,
        Industry1,
        Industry2,
        CustomerType,
        GlobalUltimateDUNSNumber,
        OEMSegment,
        CreatedDate,
        DunsName_HQ
    FROM bi_dds.DimCustomerMaster;
    """
)
# Out:
#    CustomerMasterKey                               AccountName   State  \
# 0                 -1                                         ?       ?
# 1            2113355               ABC ELECTRICAL SERVICES LLC      IA
# 2            2113356           Arrendadora Capela S.A. de C.V.     GRO
# 3            2113357                                    DuPont      GA
# 4            2113358                      Eagle Claw Midstream      TX
# 5            2113359                       Ebf Enterprises Inc      NC
# 6            2113360                          EGIL ENG & CO AS
# 7            2113361  Equipos Y Refacciones R.Y.E. S.A. De C.V     MEX
# 8            2113362  Fabricaciones De Inoxidable S.A. de C.V.     CHI
# 9            2113363                                Farmer S.A  Itapua
#
#              Office         Region   Country    Status             Industry1  \
# 0                 ?              ?         ?         ?                     ?
# 1         Davenport  North America       USA  Inactive                 Other
# 2       Mexico City  Latin America    Mexico    Active                Mining
# 3         Nashville  North America       USA    Active  Chemicals & Plastics
# 4            Dallas  North America       USA  Inactive            Unassigned
# 5         Charlotte  North America       USA    Active                 Other
# 6  Denmark-Ballerup           EMEA    Norway    Active                 Other
# 7       Mexico City  Latin America    Mexico    Active      Waste Management
# 8       Guadalajara  Latin America    Mexico    Active                 Other
# 9               777                 Paraguay  Inactive            Unassigned
#
#   Industry2 CustomerType GlobalUltimateDUNSNumber OEMSegment  \
# 0         ?            ?                        ?          ?
# 1             Contractor
# 2               End User
# 3               End User
# 4
# 5             Contractor
# 6               End User                355793241
# 7               End User
# 8               End User
# 9
#
#           CreatedDate DunsName_HQ
# 0 1900-01-01 00:00:00        None
# 1 2019-08-19 10:42:05        None
# 2 2019-08-19 10:42:08        None
# 3 2019-08-19 10:42:25        None
# 4 2019-08-19 10:42:26        None
# 5 2019-08-19 10:42:26        None
# 6 2019-08-19 10:42:27        None
# 7 2019-08-19 10:42:28        None
# 8 2019-08-19 10:42:29        None
# 9 2019-08-19 10:42:30        None

# %% [markdown]
# # `bi_dds.FactPOS`

# %%
# Number of entries
query_db(
    """
    SELECT COUNT(*)
    FROM bi_dds.FactPOS;
    """
)
# Out:
#
# 0  70295800

# %%
# Number of distinct InfluenceBySoldToPartyKey
query_db(
    """
    SELECT COUNT(DISTINCT InfluenceBySoldToPartyKey)
    FROM bi_dds.FactPOS;
    """
)
# Out:
#
# 0  397496

# %%
# All InfluenceBySoldToPartyKey values map to CustomerMasterKey values
query_db(
    """
    SELECT COUNT(*)
    FROM bi_dds.FactPOS
    WHERE InfluenceBySoldToPartyKey NOT IN (
        SELECT DISTINCT CustomerMasterKey
        FROM bi_dds.DimCustomerMaster
    );
    """
)
# Out:
#
# 0  0

# %%
# Number of distinct customers with 2021 POS entries
query_db(
    """
    SELECT COUNT(DISTINCT InfluenceBySoldToPartyKey)
    FROM bi_dds.FactPOS
    WHERE InvoiceDateKey >= 20210101
        AND InvoiceDateKey < 20220101;
    """
)
# Out:
#
# 0  146892

# %%
# Columns of interest
query_db(
    """
    SELECT TOP 10
        InfluenceBySoldToPartyKey,
        SUM(MInvoiceDateExtendedCostAmount) AS sum_MInvoiceDateExtendedCostAmount,
        SUM(PInvoiceDateExtendedCostAmount) AS sum_PInvoiceDateExtendedCostAmount,
        SUM(PLoadDateExtendedCostAmount) AS sum_PLoadDateExtendedCostAmount,
        SUM(QuantityNumber) AS sum_QuantityNumber
    FROM bi_dds.FactPOS
    WHERE InvoiceDateKey >= 20210101
        AND InvoiceDateKey < 20220101
    GROUP BY InfluenceBySoldToPartyKey;
    """
)
# Out:
#    InfluenceBySoldToPartyKey  sum_MInvoiceDateExtendedCostAmount  \
# 0                         -1                        2.668701e+07
# 1                    2113359                        2.381094e+04
# 2                    2113360                        4.633502e+03
# 3                    2113374                        6.137360e+03
# 4                    2113376                        7.834045e+04
# 5                    2113381                        1.730970e+03
# 6                    2113389                        7.390530e+03
# 7                    2113392                        4.308009e+04
# 8                    2113395                        3.033993e+04
# 9                    2113398                        1.153141e+03
#
#    sum_PInvoiceDateExtendedCostAmount  sum_PLoadDateExtendedCostAmount  \
# 0                        2.683206e+07                     2.683045e+07
# 1                        2.381094e+04                     2.381094e+04
# 2                        4.521073e+03                     4.521073e+03
# 3                        6.137360e+03                     6.137360e+03
# 4                        7.834045e+04                     7.834045e+04
# 5                        1.730970e+03                     1.730970e+03
# 6                        7.390530e+03                     7.390530e+03
# 7                        4.308009e+04                     4.308009e+04
# 8                        3.033993e+04                     3.033993e+04
# 9                        1.116516e+03                     1.116516e+03
#
#    sum_QuantityNumber
# 0           1212443.0
# 1               595.0
# 2               272.0
# 3               235.0
# 4               484.0
# 5                31.0
# 6                58.0
# 7                75.0
# 8               117.0
# 9                24.0

# %% [markdown]
# # `bi_dds.FactInvoice`

# %%
# Number of entries
query_db(
    """
    SELECT COUNT(*)
    FROM bi_dds.FactInvoice;
    """
)
# Out:
#
# 0  14287978

# %%
# Number of distinct SoldToPartyKey
query_db(
    """
    SELECT COUNT(DISTINCT SoldToPartyKey)
    FROM bi_dds.FactInvoice;
    """
)
# Out:
#
# 0  15146

# %%
# All SoldToPartyKey values map to CustomerMasterKey values
query_db(
    """
    SELECT COUNT(*)
    FROM bi_dds.FactInvoice
    WHERE SoldToPartyKey NOT IN (
        SELECT DISTINCT CustomerMasterKey
        FROM bi_dds.DimCustomerMaster
    );
    """
)
# Out:
#
# 0  0

# %%
# Number of distinct customers with 2021 invoice entries
query_db(
    """
    SELECT COUNT(DISTINCT SoldToPartyKey)
    FROM bi_dds.FactInvoice
    WHERE InvoiceDateKey >= 20210101
        AND InvoiceDateKey < 20220101;
    """
)
# Out:
#
# 0  11222

# %%
# Columns of interest
query_db(
    """
    SELECT TOP 10
        SoldToPartyKey,
        SUM(ReportingBillingAmount) AS sum_ReportingBillingAmount,
        SUM(Quantity) AS sum_Quantity
    FROM bi_dds.FactInvoice
    WHERE InvoiceDateKey >= 20210101
        AND InvoiceDateKey < 20220101
    GROUP BY SoldToPartyKey;
    """
)
# Out:
#    SoldToPartyKey  sum_ReportingBillingAmount  sum_Quantity
# 0              -1                  8406456.45       3888.85
# 1         2114494                   118019.42         41.00
# 2         2115679                     1277.64          3.00
# 3         2116315                     9522.68         14.00
# 4         2116398                    95647.92          2.00
# 5         2116464                    83652.30          8.00
# 6         2117051                    77550.00          1.00
# 7         2117817                     3565.65          2.00
# 8         2117851                        0.00          1.00
# 9         2118021                     3211.54          2.00

# %% [markdown]
# # Joins

# %%
# Include all customers that had a POS or invoice entry in 2021
df = query_db(
    """
    WITH
        -- sum of POS amounts in 2021
        pos_query
        AS
        (
            SELECT
                InfluenceBySoldToPartyKey,
                SUM(MInvoiceDateExtendedCostAmount) AS sum_POS_MInvoiceDateExtendedCostAmount,
                SUM(PInvoiceDateExtendedCostAmount) AS sum_POS_PInvoiceDateExtendedCostAmount,
                SUM(PLoadDateExtendedCostAmount) AS sum_POS_PLoadDateExtendedCostAmount,
                SUM(QuantityNumber) AS sum_POS_QuantityNumber
            FROM GlobalMarketing_DW.bi_dds.FactPOS
            WHERE InvoiceDateKey >= 20210101
                AND InvoiceDateKey < 20220101
            GROUP BY InfluenceBySoldToPartyKey
        ),
        -- sum of invoice amounts in 2021
        invoice_query
        AS
        (
            SELECT
                SoldToPartyKey,
                SUM(ReportingBillingAmount) AS sum_Invoice_ReportingBillingAmount,
                SUM(Quantity) AS sum_Invoice_Quantity
            FROM GlobalMarketing_DW.bi_dds.FactInvoice
            WHERE InvoiceDateKey >= 20210101
                AND InvoiceDateKey < 20220101
            GROUP BY SoldToPartyKey
        ),
        -- all SoldToPartyKeys that have either POS or invoice amounts in 2021
        pos_invoice_join
        AS
        (
            SELECT
                COALESCE(p.InfluenceBySoldToPartyKey, i.SoldToPartyKey) AS SoldToPartyKey,
                p.sum_POS_MInvoiceDateExtendedCostAmount,
                p.sum_POS_PInvoiceDateExtendedCostAmount,
                p.sum_POS_PLoadDateExtendedCostAmount,
                p.sum_POS_QuantityNumber,
                i.sum_Invoice_ReportingBillingAmount,
                i.sum_Invoice_Quantity
            FROM pos_query AS p
                FULL OUTER JOIN invoice_query AS i
                ON p.InfluenceBySoldToPartyKey = i.SoldToPartyKey
        )

    SELECT
        c.CustomerMasterKey,
        c.AccountName,
        c.State,
        c.Office,
        c.Region,
        c.Country,
        c.Status,
        c.Industry1,
        c.Industry2,
        c.CustomerType,
        c.GlobalUltimateDUNSNumber,
        c.OEMSegment,
        c.CreatedDate,
        c.DunsName_HQ,
        j.sum_POS_MInvoiceDateExtendedCostAmount,
        j.sum_POS_PInvoiceDateExtendedCostAmount,
        j.sum_POS_PLoadDateExtendedCostAmount,
        j.sum_POS_QuantityNumber,
        j.sum_Invoice_ReportingBillingAmount,
        j.sum_Invoice_Quantity
    FROM
        GlobalMarketing_DW.bi_dds.DimCustomerMaster AS c,
        pos_invoice_join AS j
    WHERE c.CustomerMasterKey = j.SoldToPartyKey;
    """
)
df.to_csv("customers_02.csv")
df
# Out:
#         CustomerMasterKey                               AccountName    State  \
# 0                 2428126                    GEORG FISCHER DISA INC       OK
# 1                 4261752  Zhengzhou huakong intelligent technology    Henan
# 2                 2327482                    Cold Spring Brewing Co       MN
# 3                 2842380                AUDUBON ENGINEERING CO LLC       LA
# 4                 4259044  Terminal Maritima de Carbon S.A. de C.V.      MCH
# ...                   ...                                       ...      ...
# 153761            2321391                               REYNOLDS CO       LA
# 153762            3322940                        BARPLATS MINES LTD       NW
# 153763            2935045                                   AMS SRL
# 153764            3158126                     CHINA TOBACCO JIANGXI  Jiangxi
# 153765            2175173                  Hydro Extrusion Portland       IL
#
#                     Office         Region       Country  Status  \
# 0                   Dallas  North America           USA  Active
# 1                Zhengzhou   Asia Pacific         China  Active
# 2           Minn.-St. Paul  North America           USA  Active
# 3                  Houston  North America           USA  Active
# 4                Queretaro  Latin America        Mexico  Active
# ...                    ...            ...           ...     ...
# 153761             Houston  North America           USA  Active
# 153762  South Africa S Off           EMEA  South Africa  Active
# 153763  Italy Sales Office           EMEA         Italy  Active
# 153764               Wuhan   Asia Pacific         China  Active
# 153765             Chicago  North America           USA  Active
#
#                    Industry1 Industry2          CustomerType  \
# 0                 Automotive                             OEM
# 1         Water / Wastewater               System Integrator
# 2        Household & P. Care                        End User
# 3                  Oil & Gas            A&E, EPC, Consultant
# 4                     Mining                        End User
# ...                      ...       ...                   ...
# 153761  Rockwell Distributor             RA AUthorized Distr
# 153762                Mining                        End User
# 153763         Life Sciences                             OEM
# 153764       Food & Beverage                        End User
# 153765                Metals                        End User
#
#        GlobalUltimateDUNSNumber              OEMSegment         CreatedDate  \
# 0                     352579336  Manufacturing/Assembly 2017-07-14 23:36:32
# 1                                                       2021-04-20 20:10:27
# 2                                                       2017-01-17 09:07:49
# 3                     080860020                         2017-06-28 20:34:14
# 4                                                       2021-04-13 08:03:13
# ...                         ...                     ...                 ...
# 153761                006958474                         2017-01-17 09:01:23
# 153762                                                  2017-05-06 05:58:27
# 153763                458514390               Packaging 2017-10-07 03:29:46
# 153764                544706328                         2017-09-30 07:55:33
# 153765                515010643                         2019-08-03 08:02:33
#
#        DunsName_HQ  sum_POS_MInvoiceDateExtendedCostAmount  \
# 0             None                             169524.7100
# 1             None                              73838.1379
# 2             None                              96661.5600
# 3             None                             208268.0400
# 4             None                               3655.3900
# ...            ...                                     ...
# 153761        None                                     NaN
# 153762        None                                     NaN
# 153763        None                                     NaN
# 153764        None                                     NaN
# 153765        None                                     NaN
#
#         sum_POS_PInvoiceDateExtendedCostAmount  \
# 0                                  169524.7100
# 1                                   74419.6069
# 2                                   96661.5600
# 3                                  208268.0400
# 4                                    3655.3900
# ...                                        ...
# 153761                                     NaN
# 153762                                     NaN
# 153763                                     NaN
# 153764                                     NaN
# 153765                                     NaN
#
#         sum_POS_PLoadDateExtendedCostAmount  sum_POS_QuantityNumber  \
# 0                               169524.7100                  5900.0
# 1                                74419.6069                   406.0
# 2                                96661.5600                   356.0
# 3                               208268.0400                   116.0
# 4                                 3655.3900                    15.0
# ...                                     ...                     ...
# 153761                                  NaN                     NaN
# 153762                                  NaN                     NaN
# 153763                                  NaN                     NaN
# 153764                                  NaN                     NaN
# 153765                                  NaN                     NaN
#
#         sum_Invoice_ReportingBillingAmount  sum_Invoice_Quantity
# 0                                      NaN                   NaN
# 1                                      NaN                   NaN
# 2                                      NaN                   NaN
# 3                                      NaN                   NaN
# 4                                      NaN                   NaN
# ...                                    ...                   ...
# 153761                          6507329.69             737808.55
# 153762                            16260.96                  5.00
# 153763                            89778.34                158.00
# 153764                           411999.93                  2.25
# 153765                             5528.00                 12.00
#
# [153766 rows x 20 columns]

# %%
# Check entries for specific account name
def query_account_name(account_name):
    return query_db(
        """
        WITH
            -- sum of POS amounts in 2021
            pos_query
            AS
            (
                SELECT
                    InfluenceBySoldToPartyKey,
                    SUM(MInvoiceDateExtendedCostAmount) AS sum_POS_MInvoiceDateExtendedCostAmount,
                    SUM(PInvoiceDateExtendedCostAmount) AS sum_POS_PInvoiceDateExtendedCostAmount,
                    SUM(PLoadDateExtendedCostAmount) AS sum_POS_PLoadDateExtendedCostAmount,
                    SUM(QuantityNumber) AS sum_POS_QuantityNumber
                FROM GlobalMarketing_DW.bi_dds.FactPOS
                WHERE InvoiceDateKey >= 20210101
                    AND InvoiceDateKey < 20220101
                GROUP BY InfluenceBySoldToPartyKey
            ),
            -- sum of invoice amounts in 2021
            invoice_query
            AS
            (
                SELECT
                    SoldToPartyKey,
                    SUM(ReportingBillingAmount) AS sum_Invoice_ReportingBillingAmount,
                    SUM(Quantity) AS sum_Invoice_Quantity
                FROM GlobalMarketing_DW.bi_dds.FactInvoice
                WHERE InvoiceDateKey >= 20210101
                    AND InvoiceDateKey < 20220101
                GROUP BY SoldToPartyKey
            ),
            -- all SoldToPartyKeys that have either POS or invoice amounts in 2021
            pos_invoice_join
            AS
            (
                SELECT
                    COALESCE(p.InfluenceBySoldToPartyKey, i.SoldToPartyKey) AS SoldToPartyKey,
                    p.sum_POS_MInvoiceDateExtendedCostAmount,
                    p.sum_POS_PInvoiceDateExtendedCostAmount,
                    p.sum_POS_PLoadDateExtendedCostAmount,
                    p.sum_POS_QuantityNumber,
                    i.sum_Invoice_ReportingBillingAmount,
                    i.sum_Invoice_Quantity
                FROM pos_query AS p
                    FULL OUTER JOIN invoice_query AS i
                    ON p.InfluenceBySoldToPartyKey = i.SoldToPartyKey
            )

        SELECT
            c.CustomerMasterKey,
            c.AccountName,
            c.State,
            c.Office,
            c.Region,
            c.Country,
            c.Status,
            c.Industry1,
            c.Industry2,
            c.CustomerType,
            c.GlobalUltimateDUNSNumber,
            c.OEMSegment,
            c.CreatedDate,
            c.DunsName_HQ,
            j.sum_POS_MInvoiceDateExtendedCostAmount,
            j.sum_POS_PInvoiceDateExtendedCostAmount,
            j.sum_POS_PLoadDateExtendedCostAmount,
            j.sum_POS_QuantityNumber,
            j.sum_Invoice_ReportingBillingAmount,
            j.sum_Invoice_Quantity
        FROM
            GlobalMarketing_DW.bi_dds.DimCustomerMaster AS c,
            pos_invoice_join AS j
        WHERE c.CustomerMasterKey = j.SoldToPartyKey
            AND c.AccountName = ?;
        """,
        [account_name],
    )

# %%
query_account_name("Global Process Automation")
# Out:
#    CustomerMasterKey                AccountName State     Office  \
# 0            3387182  Global Process Automation    NC  Charlotte
# 1            2184278  Global Process Automation    TN  Nashville
# 2            2142956  Global Process Automation    VA  Charlotte
# 3            2128156  Global Process Automation    WA    Seattle
#
#           Region Country  Status        Industry1      Industry2  \
# 0  North America     USA  Active     Pulp & Paper  Life Sciences
# 1  North America     USA  Active            Other
# 2  North America     USA  Active       Unassigned
# 3  North America     USA  Active  Food & Beverage  Life Sciences
#
#         CustomerType GlobalUltimateDUNSNumber OEMSegment         CreatedDate  \
# 0  System Integrator                                     2017-01-17 09:34:07
# 1  System Integrator                                     2019-05-31 05:17:05
# 2  System Integrator                                     2018-10-31 04:58:36
# 3  System Integrator                                     2019-10-05 03:04:09
#
#   DunsName_HQ  sum_POS_MInvoiceDateExtendedCostAmount  \
# 0        None                               158692.60
# 1        None                                17865.08
# 2        None                                 1186.40
# 3        None                                 6648.24
#
#    sum_POS_PInvoiceDateExtendedCostAmount  \
# 0                               158692.60
# 1                                17865.08
# 2                                 1186.40
# 3                                 6648.24
#
#    sum_POS_PLoadDateExtendedCostAmount  sum_POS_QuantityNumber  \
# 0                            158692.60                  1048.0
# 1                             17865.08                     4.0
# 2                              1186.40                     0.0
# 3                              6648.24                     5.0
#
#   sum_Invoice_ReportingBillingAmount sum_Invoice_Quantity
# 0                               None                 None
# 1                               None                 None
# 2                               None                 None
# 3                               None                 None

# %%
query_account_name("NHP Electrical Engineering Products Pty")
# Out:
#    CustomerMasterKey                              AccountName State  \
# 0            2131612  NHP Electrical Engineering Products Pty   VIC
# 1            2121838  NHP Electrical Engineering Products Pty   QLD
# 2            2149989  NHP Electrical Engineering Products Pty   AKL
# 3            2134958  NHP Electrical Engineering Products Pty    SA
# 4            2131608  NHP Electrical Engineering Products Pty    WA
#
#                  Office        Region      Country  Status Industry1  \
# 0     Victoria/Tasmania  Asia Pacific    Australia  Active     Other
# 1            Queensland  Asia Pacific    Australia  Active     Other
# 2           New Zealand  Asia Pacific  New Zealand  Active     Other
# 3  South Aust NorthTerr  Asia Pacific    Australia  Active     Other
# 4     Western Australia  Asia Pacific    Australia  Active     Other
#
#   Industry2 CustomerType GlobalUltimateDUNSNumber OEMSegment  \
# 0               End User                748231735
# 1               End User                000000000
# 2               End User                000000000
# 3               End User                754033702
# 4               End User
#
#           CreatedDate DunsName_HQ  sum_POS_MInvoiceDateExtendedCostAmount  \
# 0 2018-10-09 17:07:40        None                             115868.7892
# 1 2019-09-23 16:26:50        None                              98465.8865
# 2 2018-10-09 09:54:45        None                             222928.7314
# 3 2018-09-19 18:35:02        None                              34552.7562
# 4 2018-10-09 09:54:50        None                              71411.7925
#
#    sum_POS_PInvoiceDateExtendedCostAmount  \
# 0                             113083.1738
# 1                              96606.8816
# 2                             206669.8773
# 3                              33162.1454
# 4                              70345.4730
#
#    sum_POS_PLoadDateExtendedCostAmount  sum_POS_QuantityNumber  \
# 0                          113083.1738                   332.0
# 1                           96606.8816                   147.0
# 2                          206669.8773                   918.0
# 3                           33162.1454                    29.0
# 4                           70345.4730                   166.0
#
#   sum_Invoice_ReportingBillingAmount sum_Invoice_Quantity
# 0                               None                 None
# 1                               None                 None
# 2                               None                 None
# 3                               None                 None
# 4                               None                 None

# %%
query_account_name("Heavy Mineral Developments Pty Ltd")
# Out:
#    CustomerMasterKey                         AccountName State  \
# 0            3146780  Heavy Mineral Developments Pty Ltd   QLD
# 1            2142437  Heavy Mineral Developments Pty Ltd   NSW
#
#             Office        Region    Country  Status Industry1 Industry2  \
# 0       Queensland  Asia Pacific  Australia  Active    Mining
# 1  New South Wales  Asia Pacific  Australia  Active    Mining
#
#   CustomerType GlobalUltimateDUNSNumber OEMSegment         CreatedDate  \
# 0          OEM                000000000    Process 2017-09-22 02:52:37
# 1          OEM                             Process 2018-09-28 12:49:58
#
#   DunsName_HQ  sum_POS_MInvoiceDateExtendedCostAmount  \
# 0        None                               1012.8888
# 1        None                                527.7768
#
#    sum_POS_PInvoiceDateExtendedCostAmount  \
# 0                                 1030.08
# 1                                  515.04
#
#    sum_POS_PLoadDateExtendedCostAmount  sum_POS_QuantityNumber  \
# 0                              1030.08                     2.0
# 1                               515.04                     1.0
#
#   sum_Invoice_ReportingBillingAmount sum_Invoice_Quantity
# 0                               None                 None
# 1                               None                 None
