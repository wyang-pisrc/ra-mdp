# %%
# Read config
import configparser

config = configparser.ConfigParser()
config.read("config.secret")
# Out:
# ['config.secret']

# %% [markdown]
# # ELOQUA

# %%
import requests

# Credentials saved in 1password under "Eloqua API"
AUTH = (config["Eloqua"]["username"], config["Eloqua"]["password"])
ELOQUA_URL = "https://secure.p01.eloqua.com/API/REST/2.0"


def get_eloqua(path):
    api_url = ELOQUA_URL + path
    response = requests.get(api_url, auth=AUTH)
    return response.json()

# %%
# Get schema for all lead records
get_eloqua("/assets/customObject/462")
# Out:
# {'type': 'CustomObject',
#  'id': '462',
#  'createdAt': '1430937353',
#  'createdBy': '108',
#  'depth': 'complete',
#  'description': 'Inbound only Sync from DCRM (SFA)',
#  'folderId': '30740',
#  'name': 'DCRM - ALL Leads',
#  'updatedAt': '1614100345',
#  'updatedBy': '108',
#  'deleteLinkedCustomObjectData': 'false',
#  'displayNameFieldId': '6782',
#  'fields': [{'type': 'CustomObjectField',
#    'id': '6772',
#    'depth': 'complete',
#    'name': 'Email Address',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Email_Address1'},
#   {'type': 'CustomObjectField',
#    'id': '15579',
#    'depth': 'complete',
#    'name': 'DCRM Lead ID',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'DCRM___Lead_ID1'},
#   {'type': 'CustomObjectField',
#    'id': '6783',
#    'depth': 'complete',
#    'name': 'LMP Lead ID',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Lead_Portal_ID1'},
#   {'type': 'CustomObjectField',
#    'id': '6773',
#    'depth': 'complete',
#    'name': 'DCRM Contact ID',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'MSCRM_Online___Contact_ID1'},
#   {'type': 'CustomObjectField',
#    'id': '6791',
#    'depth': 'complete',
#    'name': 'DCRM Campaign Name',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Source_Campaign1'},
#   {'type': 'CustomObjectField',
#    'id': '20563',
#    'depth': 'complete',
#    'name': 'DCRM Campaign ID',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'DCRM___Campaign_ID1'},
#   {'type': 'CustomObjectField',
#    'id': '6780',
#    'depth': 'complete',
#    'name': 'Status',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Status1',
#    'optionListId': '24097'},
#   {'type': 'CustomObjectField',
#    'id': '6781',
#    'depth': 'complete',
#    'name': 'Status Reason',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Status_Reason1',
#    'optionListId': '24089'},
#   {'type': 'CustomObjectField',
#    'id': '6782',
#    'depth': 'complete',
#    'name': 'Lead Name',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Topic1'},
#   {'type': 'CustomObjectField',
#    'id': '6788',
#    'depth': 'complete',
#    'name': 'Lead Description',
#    'dataType': 'largeText',
#    'displayType': 'textArea',
#    'internalName': 'Description1'},
#   {'type': 'CustomObjectField',
#    'id': '6815',
#    'depth': 'complete',
#    'name': 'Additional Comments',
#    'dataType': 'largeText',
#    'displayType': 'textArea',
#    'internalName': 'Additional_Comments1'},
#   {'type': 'CustomObjectField',
#    'id': '6787',
#    'depth': 'complete',
#    'name': 'Q&A',
#    'dataType': 'largeText',
#    'displayType': 'textArea',
#    'internalName': 'Q_A1'},
#   {'type': 'CustomObjectField',
#    'id': '6789',
#    'depth': 'complete',
#    'name': 'High Level Interest',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'High_Level_Interest1'},
#   {'type': 'CustomObjectField',
#    'id': '6785',
#    'depth': 'complete',
#    'name': 'Working with RA or Dist',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Working_with_RA_or_Dist1',
#    'optionListId': '24638'},
#   {'type': 'CustomObjectField',
#    'id': '6786',
#    'depth': 'complete',
#    'name': 'Active Need',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Active_Need1',
#    'optionListId': '24638'},
#   {'type': 'CustomObjectField',
#    'id': '6784',
#    'depth': 'complete',
#    'name': 'Requested Further Contact',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Requested_Further_Contact1',
#    'optionListId': '24638'},
#   {'type': 'CustomObjectField',
#    'id': '6818',
#    'depth': 'complete',
#    'name': 'Estimated Revenue',
#    'dataType': 'numeric',
#    'displayType': 'text',
#    'internalName': 'Estimated_Revenue1'},
#   {'type': 'CustomObjectField',
#    'id': '15581',
#    'depth': 'complete',
#    'name': 'Specification Position',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Specification_Position1'},
#   {'type': 'CustomObjectField',
#    'id': '20567',
#    'depth': 'complete',
#    'name': 'DCRM Owner Name',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'DCRM_Owner_Name1'},
#   {'type': 'CustomObjectField',
#    'id': '6817',
#    'depth': 'complete',
#    'name': 'DCRM Owner Id',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Owner1'},
#   {'type': 'CustomObjectField',
#    'id': '6775',
#    'depth': 'complete',
#    'name': 'Sales Accepted',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Sales_Accepted1',
#    'optionListId': '24638'},
#   {'type': 'CustomObjectField',
#    'id': '6778',
#    'depth': 'complete',
#    'name': 'Sales Rejected Reason',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Sales_Rejected_Reason1',
#    'optionListId': '24633'},
#   {'type': 'CustomObjectField',
#    'id': '6777',
#    'depth': 'complete',
#    'name': 'Sales Qualified',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Sales_Qualified1',
#    'optionListId': '24638'},
#   {'type': 'CustomObjectField',
#    'id': '6776',
#    'depth': 'complete',
#    'name': 'Sales Disqualify Reason',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Sales_Disqualify_Reason1',
#    'optionListId': '24074'},
#   {'type': 'CustomObjectField',
#    'id': '15580',
#    'depth': 'complete',
#    'name': 'Reroute to Distributor',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Reroute_to_Distributor1',
#    'optionListId': '10166'},
#   {'type': 'CustomObjectField',
#    'id': '20351',
#    'depth': 'complete',
#    'name': 'Demand Source',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Demand_Source1',
#    'optionListId': '24636'},
#   {'type': 'CustomObjectField',
#    'id': '6814',
#    'depth': 'complete',
#    'name': 'Was Tele Performed?',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Was_Tele_Performed_1',
#    'optionListId': '10166'},
#   {'type': 'CustomObjectField',
#    'id': '7935',
#    'depth': 'complete',
#    'name': 'Tele Owner Id',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'MSCRM_Tele_Owner_Id1'},
#   {'type': 'CustomObjectField',
#    'id': '6825',
#    'depth': 'complete',
#    'name': 'Tele Accepted',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Tele_Accepted1',
#    'optionListId': '24637'},
#   {'type': 'CustomObjectField',
#    'id': '6829',
#    'depth': 'complete',
#    'name': 'Tele Rejection Reason',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Tele_Rejection_Reason1',
#    'optionListId': '24634'},
#   {'type': 'CustomObjectField',
#    'id': '6828',
#    'depth': 'complete',
#    'name': 'Tele Qualified',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Tele_Qualified1',
#    'optionListId': '24637'},
#   {'type': 'CustomObjectField',
#    'id': '6827',
#    'depth': 'complete',
#    'name': 'Tele Disqualify Reason',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Tele_Disqualify_Reason1',
#    'optionListId': '24635'},
#   {'type': 'CustomObjectField',
#    'id': '8192',
#    'depth': 'complete',
#    'name': 'Tele Purchase Timeframe',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Tele_Purchase_Timeframe1'},
#   {'type': 'CustomObjectField',
#    'id': '8193',
#    'depth': 'complete',
#    'name': 'Tele Budget Amount',
#    'dataType': 'numeric',
#    'displayType': 'text',
#    'internalName': 'Tele_Budget_Amount1'},
#   {'type': 'CustomObjectField',
#    'id': '8194',
#    'depth': 'complete',
#    'name': 'Tele Purchase Process',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Tele_Purchase_Process1'},
#   {'type': 'CustomObjectField',
#    'id': '8195',
#    'depth': 'complete',
#    'name': 'Tele Current Situation',
#    'dataType': 'largeText',
#    'displayType': 'textArea',
#    'internalName': 'Tele_Current_Situation1'},
#   {'type': 'CustomObjectField',
#    'id': '8196',
#    'depth': 'complete',
#    'name': 'Tele Customer Need',
#    'dataType': 'largeText',
#    'displayType': 'textArea',
#    'internalName': 'Tele_Customer_Need1'},
#   {'type': 'CustomObjectField',
#    'id': '8197',
#    'depth': 'complete',
#    'name': 'Tele Customer Pain Points',
#    'dataType': 'largeText',
#    'displayType': 'textArea',
#    'internalName': 'Tele_Customer_Pain_Points1'},
#   {'type': 'CustomObjectField',
#    'id': '8199',
#    'depth': 'complete',
#    'name': 'Tele Additional Q&A',
#    'dataType': 'largeText',
#    'displayType': 'textArea',
#    'internalName': 'Tele_Additional_QA1'},
#   {'type': 'CustomObjectField',
#    'id': '8200',
#    'depth': 'complete',
#    'name': 'Tele Lead Feedback',
#    'dataType': 'largeText',
#    'displayType': 'textArea',
#    'internalName': 'Tele_Lead_Feedback1'},
#   {'type': 'CustomObjectField',
#    'id': '29746',
#    'depth': 'complete',
#    'name': 'Lead Acceptance Due Date',
#    'dataType': 'date',
#    'displayType': 'text',
#    'internalName': 'Lead_Acceptance_Due_Date1'},
#   {'type': 'CustomObjectField',
#    'id': '30148',
#    'depth': 'complete',
#    'name': 'Lead Qualification Due Date',
#    'dataType': 'date',
#    'displayType': 'text',
#    'internalName': 'Lead_Qualification_Due_Date1'},
#   {'type': 'CustomObjectField',
#    'id': '15583',
#    'depth': 'complete',
#    'name': 'OLD DO NOT USE Lead Qualification Date Due',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Lead_Qualification_Date_Due1'},
#   {'type': 'CustomObjectField',
#    'id': '7888',
#    'depth': 'complete',
#    'name': 'Stage Timestamp TQL',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Stage_Timestamp_TQL1'},
#   {'type': 'CustomObjectField',
#    'id': '7887',
#    'depth': 'complete',
#    'name': 'Stage Timestamp TAL',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Stage_Timestamp_TAL1'},
#   {'type': 'CustomObjectField',
#    'id': '15582',
#    'depth': 'complete',
#    'name': 'Date Tele Assigned',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Date_Tele_Assigned1'},
#   {'type': 'CustomObjectField',
#    'id': '7884',
#    'depth': 'complete',
#    'name': 'Stage Timestamp SAL',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Stage_Timestamp_SAL1'},
#   {'type': 'CustomObjectField',
#    'id': '7886',
#    'depth': 'complete',
#    'name': 'Stage Timestamp SQL',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Stage_Timestamp_SQL1'},
#   {'type': 'CustomObjectField',
#    'id': '7936',
#    'depth': 'complete',
#    'name': 'Stage Timestamp Ready for Export',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Stage_Timestamp_Ready_for_Export1'},
#   {'type': 'CustomObjectField',
#    'id': '7934',
#    'depth': 'complete',
#    'name': 'Ready for Export',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Ready_for_Export1'},
#   {'type': 'CustomObjectField',
#    'id': '21210',
#    'depth': 'complete',
#    'name': 'DCRM Qualifying Opp GUID',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'DCRM_Qualifying_Opp_GUID1'},
#   {'type': 'CustomObjectField',
#    'id': '27466',
#    'depth': 'complete',
#    'name': 'DCRM Currency GUID',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'DCRM_Currency_GUID1'},
#   {'type': 'CustomObjectField',
#    'id': '6819',
#    'depth': 'complete',
#    'name': 'DCRM Lead Created On',
#    'dataType': 'date',
#    'displayType': 'text',
#    'internalName': 'Lead_Created_On1'},
#   {'type': 'CustomObjectField',
#    'id': '6824',
#    'depth': 'complete',
#    'name': 'DCRM Lead Modified On',
#    'dataType': 'date',
#    'displayType': 'text',
#    'internalName': 'Lead_Modified_On1'},
#   {'type': 'CustomObjectField',
#    'id': '27198',
#    'depth': 'complete',
#    'name': 'DCRM Lead Stage',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'DCRM_Lead_Stage1',
#    'optionListId': '24640'},
#   {'type': 'CustomObjectField',
#    'id': '6822',
#    'depth': 'complete',
#    'name': 'LMP Status',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'LMP_Status1'},
#   {'type': 'CustomObjectField',
#    'id': '6823',
#    'depth': 'complete',
#    'name': 'LMP Status Reason',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'LMP_Status_Reason1'},
#   {'type': 'CustomObjectField',
#    'id': '27204',
#    'depth': 'complete',
#    'name': 'LMP Status Reason (DCRM)',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'LMP_Status_Reason_DCRM1'},
#   {'type': 'CustomObjectField',
#    'id': '24364',
#    'depth': 'complete',
#    'name': 'LMP Status Reason Notes',
#    'dataType': 'largeText',
#    'displayType': 'textArea',
#    'internalName': 'LMP_Status_Reason_Notes1'},
#   {'type': 'CustomObjectField',
#    'id': '7862',
#    'depth': 'complete',
#    'name': 'LMP Opportunity Status',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'LMP_Opportunity_Status1'},
#   {'type': 'CustomObjectField',
#    'id': '6820',
#    'depth': 'complete',
#    'name': 'LMP Opportunity Product',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'LMP_Opportunity_Product1'},
#   {'type': 'CustomObjectField',
#    'id': '6821',
#    'depth': 'complete',
#    'name': 'LMP Opportunity Value',
#    'dataType': 'numeric',
#    'displayType': 'text',
#    'internalName': 'LMP_Opportunity_Value1'},
#   {'type': 'CustomObjectField',
#    'id': '24362',
#    'depth': 'complete',
#    'name': 'LMP Opportunity Date Created',
#    'dataType': 'date',
#    'displayType': 'text',
#    'internalName': 'LMP_Opportunity_Date_Created1'},
#   {'type': 'CustomObjectField',
#    'id': '24363',
#    'depth': 'complete',
#    'name': 'LMP Opportunity Date Modified',
#    'dataType': 'date',
#    'displayType': 'text',
#    'internalName': 'LMP_Opportunity_Date_Modified1'},
#   {'type': 'CustomObjectField',
#    'id': '6830',
#    'depth': 'complete',
#    'name': 'LMP Date Created',
#    'dataType': 'date',
#    'displayType': 'text',
#    'internalName': 'LMP_Date_Created1'},
#   {'type': 'CustomObjectField',
#    'id': '28349',
#    'depth': 'complete',
#    'name': 'LMP Date Modified',
#    'dataType': 'date',
#    'displayType': 'text',
#    'internalName': 'LMP_Date_Modified1'},
#   {'type': 'CustomObjectField',
#    'id': '6833',
#    'depth': 'complete',
#    'name': 'LMP Date Assigned',
#    'dataType': 'date',
#    'displayType': 'text',
#    'internalName': 'LMP_Date_Assigned1'},
#   {'type': 'CustomObjectField',
#    'id': '6831',
#    'depth': 'complete',
#    'name': 'LMP Date Accepted',
#    'dataType': 'date',
#    'displayType': 'text',
#    'internalName': 'LMP_Date_Accepted1'},
#   {'type': 'CustomObjectField',
#    'id': '6832',
#    'depth': 'complete',
#    'name': 'LMP Date Closed',
#    'dataType': 'date',
#    'displayType': 'text',
#    'internalName': 'LMP_Date_Closed1'},
#   {'type': 'CustomObjectField',
#    'id': '6834',
#    'depth': 'complete',
#    'name': 'LMP Owner Email',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'LMP_Assigned_Rep_Email1'},
#   {'type': 'CustomObjectField',
#    'id': '24365',
#    'depth': 'complete',
#    'name': 'LMP Salesrep Notes',
#    'dataType': 'largeText',
#    'displayType': 'textArea',
#    'internalName': 'LMP_Salesrep_Notes1'},
#   {'type': 'CustomObjectField',
#    'id': '24366',
#    'depth': 'complete',
#    'name': 'LMP Dataset Region',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'LMP_Dataset_Region1'},
#   {'type': 'CustomObjectField',
#    'id': '29738',
#    'depth': 'complete',
#    'name': 'LMP DCRM Processing Flag',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'LMP_DCRM_Processing_Flag1'},
#   {'type': 'CustomObjectField',
#    'id': '6774',
#    'depth': 'complete',
#    'name': 'MSCRM NALM - Lead ID',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'MSCRM_Online_Lead_ID1'},
#   {'type': 'CustomObjectField',
#    'id': '6790',
#    'depth': 'complete',
#    'name': 'MSCRM NALM - Campaign ID',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'MSCRM_Online_Campaign_ID1'},
#   {'type': 'CustomObjectField',
#    'id': '6779',
#    'depth': 'complete',
#    'name': 'Business Process Stage',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Sales_Stage1'},
#   {'type': 'CustomObjectField',
#    'id': '6826',
#    'depth': 'complete',
#    'name': 'Tele Completed Call',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Tele_Completed_Call1'},
#   {'type': 'CustomObjectField',
#    'id': '7885',
#    'depth': 'complete',
#    'name': 'Stage Timestamp SAP Data',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Stage_Timestamp_SAP_Data1'},
#   {'type': 'CustomObjectField',
#    'id': '7889',
#    'depth': 'complete',
#    'name': 'Exported to SAP On',
#    'dataType': 'date',
#    'displayType': 'text',
#    'internalName': 'Exported_to_SAP_On1'},
#   {'type': 'CustomObjectField',
#    'id': '7863',
#    'depth': 'complete',
#    'name': 'SAP Campaign ID',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'SAP_Campaign_ID1'}]}

# %% [markdown]
# Fields of interest:
#
# ```py
#   {'type': 'CustomObjectField',
#    'id': '6772',
#    'depth': 'complete',
#    'name': 'Email Address',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'Email_Address1'}
#
#   {'type': 'CustomObjectField',
#    'id': '6780',
#    'depth': 'complete',
#    'name': 'Status',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Status1',
#    'optionListId': '24097'}
#
#   {'type': 'CustomObjectField',
#    'id': '6775',
#    'depth': 'complete',
#    'name': 'Sales Accepted',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Sales_Accepted1',
#    'optionListId': '24638'}
#
#   {'type': 'CustomObjectField',
#    'id': '6777',
#    'depth': 'complete',
#    'name': 'Sales Qualified',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Sales_Qualified1',
#    'optionListId': '24638'}
#
#   {'type': 'CustomObjectField',
#    'id': '6825',
#    'depth': 'complete',
#    'name': 'Tele Accepted',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Tele_Accepted1',
#    'optionListId': '24637'}
#
#   {'type': 'CustomObjectField',
#    'id': '6828',
#    'depth': 'complete',
#    'name': 'Tele Qualified',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'Tele_Qualified1',
#    'optionListId': '24637'}
#
#   {'type': 'CustomObjectField',
#    'id': '27198',
#    'depth': 'complete',
#    'name': 'DCRM Lead Stage',
#    'dataType': 'text',
#    'displayType': 'singleSelect',
#    'internalName': 'DCRM_Lead_Stage1',
#    'optionListId': '24640'}
#
#   {'type': 'CustomObjectField',
#    'id': '6822',
#    'depth': 'complete',
#    'name': 'LMP Status',
#    'dataType': 'text',
#    'displayType': 'text',
#    'internalName': 'LMP_Status1'}
#
#   {'type': 'CustomObjectField',
#    'id': '6821',
#    'depth': 'complete',
#    'name': 'LMP Opportunity Value',
#    'dataType': 'numeric',
#    'displayType': 'text',
#    'internalName': 'LMP_Opportunity_Value1'}
# ```

# %% [markdown]
# # Adobe Analytics

# %%
import requests
import jwt
import datetime

# Credentials saved on 1password under "Adobe Analytics API"

JWT_URL = "https://ims-na1.adobelogin.com/ims/exchange/jwt/"

# From Adobe Developer Console + generated expiry date
JWT_PAYLOAD = {
    "iss": config["Adobe Analytics"]["jwt_iss"],
    "sub": config["Adobe Analytics"]["jwt_sub"],
    "https://ims-na1.adobelogin.com/s/ent_analytics_bulk_ingest_sdk": True,
    "aud": config["Adobe Analytics"]["jwt_aud"],
    "exp": int((datetime.datetime.now() + datetime.timedelta(days=1)).strftime("%s")),
}
jwt_payload_encrypted = jwt.encode(
    JWT_PAYLOAD, config["Adobe Analytics"]["private_key"], algorithm="RS256"
)

access_token_request_payload = {
    "client_id": config["Adobe Analytics"]["client_id"],
    "client_secret": config["Adobe Analytics"]["client_secret"],
    "jwt_token": jwt_payload_encrypted,
}

response = requests.post(url=JWT_URL, data=access_token_request_payload)
ACCESS_TOKEN = response.json()["access_token"]

# Get global company ID
DISCOVERY_URL = "https://analytics.adobe.io/discovery/me"
DISCOVERY_HEADER = {
    "Accept": "application/json",
    "Authorization": f"Bearer {ACCESS_TOKEN}",
    "x-api-key": config["Adobe Analytics"]["client_id"],
}
response = requests.get(url=DISCOVERY_URL, headers=DISCOVERY_HEADER)
GLOBAL_COMPANY_ID = response.json()["imsOrgs"][0]["companies"][0]["globalCompanyId"]
# globalCompanyId: rockwe1

response.json()
# Out:
# {'imsUserId': 'E4231E6061F8463E0A495C3E@techacct.adobe.com',
#  'imsOrgs': [{'imsOrgId': '355141B554736E1B0A4C98A7@AdobeOrg',
#    'companies': [{'globalCompanyId': 'rockwe1',
#      'companyName': 'rockwellautomation',
#      'apiRateLimitPolicy': 'aa_api_tier10_tp',
#      'dpc': 'pnw'}]}]}

# %%
# This is the complete HEADER
HEADER = {
    "Accept": "application/json",
    "Authorization": f"Bearer {ACCESS_TOKEN}",
    "x-api-key": config["Adobe Analytics"]["client_id"],
    "x-proxy-global-company-id": GLOBAL_COMPANY_ID,
}
BASE_URL = f"https://analytics.adobe.io/api/{GLOBAL_COMPANY_ID}"

# Get report suite ID
FIND_RSID_URL = BASE_URL + "/collections/suites"
response = requests.get(url=FIND_RSID_URL, headers=HEADER)
RSID = response.json()["content"][0]["rsid"]

# Use BASE_URL + endpoint + RSID_ADDON for requests
RSID_ADDON = f"?rsid={RSID}"
response.json()["content"]
# Out:
# [{'collectionItemType': 'reportsuite',
#   'id': 'rokrockwell-locator-dev',
#   'rsid': 'rokrockwell-locator-dev',
#   'name': 'Rockwell Corp Locator (Dev)'},
#  {'collectionItemType': 'reportsuite',
#   'id': 'rokrockwell-partner-dev',
#   'rsid': 'rokrockwell-partner-dev',
#   'name': 'Rockwell Corp Partner (Dev)'},
#  {'collectionItemType': 'reportsuite',
#   'id': 'rokrockwellassetsinsights',
#   'rsid': 'rokrockwellassetsinsights',
#   'name': 'AEM Assets Insights (prod)'},
#  {'collectionItemType': 'reportsuite',
#   'id': 'rokrockwellassetsinsightsdev',
#   'rsid': 'rokrockwellassetsinsightsdev',
#   'name': 'AEM Assets Insights (Dev)'},
#  {'collectionItemType': 'reportsuite',
#   'id': 'rokrockwellcorpdev',
#   'rsid': 'rokrockwellcorpdev',
#   'name': 'Rockwell Corp (Dev)'},
#  {'collectionItemType': 'reportsuite',
#   'id': 'rokrockwellcorpprod',
#   'rsid': 'rokrockwellcorpprod',
#   'name': 'Rockwell Corp (Prod)'},
#  {'collectionItemType': 'reportsuite',
#   'id': 'rokrockwelllocatorprod',
#   'rsid': 'rokrockwelllocatorprod',
#   'name': 'Rockwell Corp Locator (Prod)'},
#  {'collectionItemType': 'reportsuite',
#   'id': 'rokrockwellpartnerprod',
#   'rsid': 'rokrockwellpartnerprod',
#   'name': 'Rockwell Corp Partner (Prod)'},
#  {'collectionItemType': 'virtualreportsuite',
#   'id': 'vrs_rockwe1_productionexcludeint',
#   'rsid': 'vrs_rockwe1_productionexcludeint',
#   'name': 'Prod (Exclude Internal)'}]

# %%
import pandas as pd

url = BASE_URL + "/metrics" + RSID_ADDON
response = requests.get(url=url, headers=HEADER)
df = pd.DataFrame(response.json())
df
# Out:
#                                  id                                 title  \
# 0          metrics/averagepagedepth                    Average Page Depth
# 1    metrics/averagetimespentonpage  Average Time Spent on Page (seconds)
# 2    metrics/averagetimespentonsite  Average Time Spent on Site (seconds)
# 3         metrics/averagevisitdepth                   Average Visit Depth
# 4                metrics/bouncerate                           Bounce Rate
# ..                              ...                                   ...
# 200         metrics/visitorsmonthly               Monthly Unique Visitors
# 201       metrics/visitorsquarterly             Quarterly Unique Visitors
# 202          metrics/visitorsweekly                Weekly Unique Visitors
# 203          metrics/visitorsyearly                Yearly Unique Visitors
# 204                  metrics/visits                                Visits
#
#                                      name     type category   support  \
# 0                      Average Page Depth      int  Traffic  [oberon]
# 1    Average Time Spent on Page (seconds)      int  Traffic        []
# 2    Average Time Spent on Site (seconds)      int  Traffic  [oberon]
# 3                     Average Visit Depth      int  Traffic        []
# 4                             Bounce Rate  percent  Traffic  [oberon]
# ..                                    ...      ...      ...       ...
# 200               Monthly Unique Visitors      int  Traffic        []
# 201             Quarterly Unique Visitors      int  Traffic        []
# 202                Weekly Unique Visitors      int  Traffic        []
# 203                Yearly Unique Visitors      int  Traffic        []
# 204                                Visits      int  Traffic  [oberon]
#
#      allocation  precision  calculated  segmentable  supportsDataGovernance  \
# 0         False        0.0       False        False                   False
# 1         False        0.0       False        False                   False
# 2         False        0.0       False        False                   False
# 3         False        0.0       False        False                   False
# 4         False        2.0        True        False                   False
# ..          ...        ...         ...          ...                     ...
# 200       False        0.0       False        False                   False
# 201       False        0.0       False        False                   False
# 202       False        0.0       False        False                   False
# 203       False        0.0       False        False                   False
# 204       False        0.0       False         True                   False
#
#      polarity description extraTitleInfo helpLink
# 0    positive         NaN            NaN      NaN
# 1    positive         NaN            NaN      NaN
# 2    positive         NaN            NaN      NaN
# 3    positive         NaN            NaN      NaN
# 4    negative         NaN            NaN      NaN
# ..        ...         ...            ...      ...
# 200  positive         NaN            NaN      NaN
# 201  positive         NaN            NaN      NaN
# 202  positive         NaN            NaN      NaN
# 203  positive         NaN            NaN      NaN
# 204  positive         NaN            NaN      NaN
#
# [205 rows x 15 columns]

# %%
POST_REPORT_URL = BASE_URL + "reports" + RSID_ADDON

START_DATE = "2022-01-01"
END_DATE = "2022-02-01"
MIDNIGHT = "T00:00:00.000"
DATE_RANGE = START_DATE + MIDNIGHT + "/" + END_DATE + MIDNIGHT

METS = ["metrics/visits", "metrics/orders", "metrics/revenue"]
METS_OBJ = [{"id": x} for x in METS]

DIM = "variables/lasttouchchannel"

REPORT_BODY = {
    "rsid": RSID,
    "globalFilters": [{"type": "dateRange", "dateRange": DATE_RANGE}],
    "metricContainer": {
        "metrics": METS_OBJ,
    },
    "dimension": DIM,
    "settings": {
        "dimensionSort": "asc",
        "limit": 5,
    },
}

response = requests.post(url=POST_REPORT_URL, headers=HEADER, json=REPORT_BODY)
# df = pd.DataFrame(response.json())
response.json()
# Out:
# {'error_code': '403025', 'message': 'Profile is not valid'}
